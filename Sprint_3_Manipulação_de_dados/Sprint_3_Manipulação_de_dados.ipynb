# %% [markdown]
# <div>
# Olá, Desejado!
#
# Meu nome é Luiz. Fico feliz em revisar seu projeto. Ao longo do texto farei algumas observações sobre melhorias no código e também farei comentários sobre suas percepções sobre o assunto. Estarei aberto a feedbacks e discussões sobre o tema.
#
# **Peço que mantenha e não altere os comentários que eu fizer por aqui para que possamos nos localizar posteriormente, ok?**
#
# Mais uma coisa, vamos utilizar um código de cores para você entender o meu feedback no seu notebook. Funciona assim:
#
# <div class="alert alert-block alert-success">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
# Sucesso. Tudo foi feito corretamente.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentário do revisor: </b> <a class="tocSkip"></a>
#
# Alerta não crítico, mas que pode ser corrigido para melhoria geral no seu código/análise.
# </div>
#
# <div class="alert alert-block alert-danger">
#
# <b>Comentário do revisor: </b> <a class="tocSkip"></a>
#
# Erro que precisa ser arrumado, caso contrário seu projeto **não** será aceito.
# </div>
#
# Você pode interagir comigo através dessa célula:
# <div class="alert alert-block alert-info">
# <b>Resposta do Aluno.</b> <a class="tocSkip"></a>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b> Comentário geral do revisor v1</b> <a class="tocSkip"></a>
# <s>
# Obrigado por enviar o seu projeto e pelo esforço de chegar até aqui. O seu projeto possui alguns pontos bem interessantes, dos quais eu destaco:
#
# - Código bem simples e estruturado
# - Análises bem detalhadas em cada etapa do projeto
# - Boas habilidades de manipulação de dados
#
# <br>
#
# Entretanto, deixei alguns comentários em alguns trechos que precisam de ajuste. Peço que trabalhe nesses pontos para avançarmos.
#
#
# <br>
# Qualquer dúvida, pode contar comigo.
#
#
# **Até breve!**
# </s>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b> Comentário geral do revisor v2</b> <a class="tocSkip"></a>
#
# Obrigado por enviar o seu projeto e fazer os ajustes sugeridos. Essa versão do seu trabalho ficou muito melhor! Espero que as sugestões sejam relevantes para projetos futuros.
#
# <br>
# Te desejo uma jornada de muito sucesso e aprendizado.
#
# <br>
#
# Qualquer dúvida, pode contar comigo.
#
# <br>
#
# **Até breve!**
#
# </div>

# %% [markdown]
# # Vamos encher o carrinho!

# %% [markdown]
# # Introdução
#
# O Instacart é uma plataforma de entrega de supermercado onde os clientes podem fazer um pedido no supermercado e depois receber sua compra, semelhante ao funcionamento do Uber Eats e do iFood. O conjunto de dados que fornecemos foi modificado a partir do original. Reduzimos o tamanho dele para que seus cálculos sejam executados mais rapidamente e incluímos valores ausentes e duplicados. Também tivemos o cuidado de preservar as distribuições dos dados originais quando fizemos as alterações.
#
# Você precisa completar três etapas. Para cada uma delas, escreva uma breve introdução descrevendo como você pretende concluir a etapa e justifique suas decisões em parágrafos explicativos a medida que você avança na solução. Escreva também uma conclusão para resumir suas conclusões e escolhas.

# %% [markdown]
# # Dicionário de dados
#
# Há cinco tabelas no conjunto de dados, e você vai precisar usar todas elas para pré-processar seus dados e fazer AED. Abaixo está um dicionário que lista as colunas de cada tabela e descreve os dados contidos nelas.
#
# - `instacart_orders.csv`: cada linha corresponde a um pedido no aplicativo da Instacart
#     - `'order_id'`: é o número que identifica cada pedido de forma exclusiva
#     - `'user_id'`: é o número de identificação exclusivo da conta de cada cliente
#     - `'order_number'`: é o número de vezes que o cliente fez um pedido
#     - `'order_dow'`: é o dia da semana em que o pedido foi feito (0 é domingo)
#     - `'order_hour_of_day'`: é a hora do dia em que o pedido foi feito
#     - `'days_since_prior_order'`: é o número de dias desde que o cliente fez seu pedido anterior
#
#
#
#
# - `products.csv`: cada linha corresponde a um produto exclusivo que os clientes podem comprar
#     - `'product_id'`: é o número de identificação unívoco de cada produto
#     - `'product_name'`: é o nome do produto
#     - `'aisle_id'`: é o número de identificação exclusivo de cada categoria de corredor do supermercado
#     - `'department_id'`: é o número de identificação exclusivo de cada categoria de departamento do supermercado
#
#
#
#
# -	`order_products.csv`: cada linha corresponde a um item incluído em um pedido
#     -	`'order_id'`: é o número que identifica cada pedido de forma exclusiva
#     -	`'product_id'`: é o número de identificação exclusivo de cada produto
#     -	`'add_to_cart_order'`: é a ordem sequencial em que cada item foi colocado no carrinho
#     -	`'reordered'`: 0 se o cliente nunca comprou o produto antes, 1 se já o comprou
#
#
#
#
# -	`aisles.csv`
#     -	`'aisle_id'`: é o número de identificação exclusivo de cada categoria de corredor do supermercado
#     -	`'aisle'`: é o nome do corredor
#
#
#
# -	`departments.csv`
#     -	`'department_id'`: é o número de identificação exclusivo de cada categoria de departamento do supermercado
#     -	`'department'`: é o nome do departamento

# %% [markdown]
# # Etapa 1. Visão geral dos dados
#
# Leia os arquivos de dados (/datasets/instacart_orders.csv, /datasets/products.csv, /datasets/aisles.csv, /datasets/departments.csv e /datasets/order_products.csv) com `pd.read_csv()` usando os parâmetros apropriados para fazer isso corretamente. Verifique as informações para cada DataFrame criado.

# %% [markdown]
# ## Plano de solução
#
# Escreva aqui seu plano para a Etapa 2. Visão geral dos dados

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np # Importe as bibliotecas

# %%
# Caminhos para os arquivos de dados
# Leitura dos arquivos CSV
df_orders = pd.read_csv('/datasets/instacart_orders.csv', sep=';')
df_products = pd.read_csv('/datasets/products.csv', sep=';')
df_aisles = pd.read_csv('/datasets/aisles.csv', sep=';')
df_departments = pd.read_csv('/datasets/departments.csv', sep=';')
df_order_products = pd.read_csv('/datasets/order_products.csv', sep=';')

# leia os conjuntos de dados em DataFrames

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
# - O conjunto de dados foi carregado corretamente usando o separador `;`.
# - O import das bibliotecas foi feito de forma correta e em uma célula separada.
# </div>

# %%
df_orders.head()
df_orders.info()# imprima as informações sobre o DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   order_id                5 non-null      int64
#  1   user_id                 5 non-null      int64
#  2   order_number            5 non-null      int64
#  3   order_dow               5 non-null      int64
#  4   order_hour_of_day       5 non-null      int64
#  5   days_since_prior_order  5 non-null      float64
# dtypes: float64(1), int64(5)
# memory usage: 368.0 bytes

# %%
df_products.head()
df_products.info()# imprima as informações sobre o DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_id     5 non-null      int64
#  1   product_name   5 non-null      object
#  2   aisle_id       5 non-null      int64
#  3   department_id  5 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 288.0+ bytes

# %%
df_aisles.head()
df_aisles.info()# imprima as informações sobre o DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   aisle_id  5 non-null      int64
#  1   aisle     5 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 208.0+ bytes

# %%
df_departments.head()
df_departments.info()# imprima as informações sobre o DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   department_id  5 non-null      int64
#  1   department     5 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 208.0+ bytes

# %%
df_order_products.head()
df_order_products.info()# imprima as informações sobre o DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   order_id           5 non-null      int64
#  1   product_id         5 non-null      int64
#  2   add_to_cart_order  5 non-null      float64
#  3   reordered          5 non-null      int64
# dtypes: float64(1), int64(3)
# memory usage: 288.0 bytes

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
# - Aqui você precisa usar os métodos `head()` e `info()` para estudo inicial dos dados.
# </div>

# %% [markdown]
# ## Conclusões
#
# Escreva aqui suas conclusões intermediárias da Etapa 1. Visão geral dos dados

# %%
#imprimi as informações do df pra analizar

# %% [markdown]
# # Etapa 2. Preparação de dados
#
# Faça o pré-processamento dos dados da seguinte maneira:
#
# -	Verifique e corrija os tipos de dados (por exemplo, certifique-se de que as colunas de ID sejam números inteiros)
# -	Identifique e preencha valores ausentes
# -	Identifique e remova valores duplicados
#
# Certifique-se de explicar que tipos de valores ausentes e duplicados você encontrou, como você os preencheu ou removeu, por que escolheu esses métodos e por que você acha que esses valores ausentes e duplicados estavam presentes no conjunto de dados.

# %% [markdown]
# ## Plano de solução
#
# Escreva aqui seu plano para a Etapa 2. Preparação de dados

# %%
#certificar-me de tipo de dados, reconhecer valores ausentes e substituilos e remover os duplificados

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
# <s>- Aqui você precisa apresentar o seu plano de solução para a etapa de preparação de dados. Peço que seja mais específico, por exemplo: fazer remoção de duplicados, preencher valores ausentes, etc.</s>
# </div>

# %% [markdown]
# ## Encontre e remova valores duplicados (e descreva por que você está fazendo suas escolhas)

# %% [markdown]
# ### DataFrame `instacart_orders`

# %%
print(df_orders.duplicated().sum())#soma total os valores duplicados
# Verificar se há pedidos duplicados
# Out:
# 15

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
# Os valores duplicados para o dataset `orders` foram verificados
# </div>

# %% [markdown]
# Há linhas duplicadas? Se sim, o que elas têm em comum?

# %%
# suma total dos duplificados é 15

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
# <s>O que as linhas duplicadas têm em comum? Qual o dia e a hora que elas aconteceram?</s>
# </div>

# %%
# Com base nas suas conclusões,

# verifique todos os pedidos feitos às 2h da manhã nas quartas-feiras 
print(df_orders.query('order_hour_of_day == 2 and order_dow == 3'))
# Out:
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 4838     2766110   162084            41          3                  2
# 5156     2190225   138285            18          3                  2
# 15506     553049    58599            13          3                  2
# 18420     382357   120200            19          3                  2
# 24691     690242    77357             2          3                  2
# ...          ...      ...           ...        ...                ...
# 457013   3384021    14881             6          3                  2
# 458816    910166   164782            18          3                  2
# 459635   1680532   106435             6          3                  2
# 468324    222962    54979            59          3                  2
# 477526   2592344    46860            38          3                  2
#
#         days_since_prior_order
# 4838                      16.0
# 5156                      11.0
# ...

# %% [markdown]
# O que esse resultado quer dizer?

# %%
#o resultado mostra que tem 15 numeros duplicados

# %%
df_orders_drop = df_orders.drop_duplicates().reset_index(drop=True)# Remova pedidos duplicados

# %%
print(df_orders_drop.duplicated().sum())# Verifique as linhas duplicadas mais uma vez
# Out:
# 0

# %%
print(df_orders_drop['user_id'].duplicated().sum())# Verifique novamente apenas os IDs de pedidos duplicados
# Out:
# 321515

# %% [markdown]
# Descreva brevemente suas conclusões e o que você fez com elas.

# %%
#ainda existem  321515 duolidicados na coluna ID

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
# <s>
# Aqui você precisa resetar os índicies do seu dataframe após a operação de remoção de duplicados para resetar os valores originais (`.reset_index(drop=True)`)
#
#
# ```python
# .drop_duplicates()
# ...
# .reset_index(drop=True)
# ...
# ```
# </s>
# </div>

# %% [markdown]
# ### DataFrame `products`

# %%
print(df_products.duplicated().sum())# Verifique se há linhas completamente duplicadas
# Out:
# 0

# %%
print(df_products['product_id'].duplicated().sum())# Verifique apenas IDs dos produtos duplicados
# Out:
# 0

# %%
products = df_products['product_name'].str.lower()
print(products.duplicated().value_counts())# Verifique apenas nomes de produtos duplicados (converta os nomes para minúsculas para uma comparação melhor)
# Out:
# False    48333
# True      1361
# Name: product_name, dtype: int64

# %%
nome_de_produto = products[~(df_products['product_name'].isna()) & df_products['product_name'].str.lower().duplicated()]
print(nome_de_produto.value_counts())
print('---------------------------------------------------------')
print('Total: ', nome_de_produto.value_counts().sum())# Verifique os nomes de produtos duplicados que não estão faltando
# Out:
# green tea with ginseng and honey                                        2
# carrot and celery sticks                                                1
# sour cream and onion potato chips                                       1
# proactive health indoor weight & hairball care with chicken cat food    1
# anchovy fillets in olive oil                                            1
#                                                                        ..
# chipotle peppers in adobo sauce                                         1
# ibuprofen tablets 200 mg                                                1
# lavender & chamomile baby powder                                        1
# american cheese slices                                                  1
# concentrace trace mineral drops                                         1
# Name: product_name, Length: 103, dtype: int64
# ---------------------------------------------------------
# Total:  104

# %% [markdown]
# Descreva brevemente suas conclusões e o que você fez com elas.

# %%
#existem produtos com nomes duplicados no total de 104

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
# <s>
# Aqui você precisa filtrar casos de valores ausentes e não duplicados. Sugestão para implementação do filtro acima:
#
# ```python
# products[~(products['product_name'].isna()) & (products['product_name'].str.lower().duplicated())]
# ```
# </s>
# </div>

# %% [markdown]
# ### DataFrame `departments`

# %%
print(df_departments.duplicated().sum())# Verifique se há linhas completamente duplicadas
# Out:
# 0

# %%
print(df_products['product_id'].duplicated().sum())# Verifique apenas se há IDs dos produtos duplicados
# Out:
# 0

# %% [markdown]
# Descreva brevemente suas conclusões e o que você fez com elas.

# %%
#primeiro vi se existe linha duplificada em todo o DF, depois especifiquei pra ver se existe na coluna id e resultado foi que nao existe valores duplicados nessq tabela

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
# <s>Existem valores duplicados nessa tabela? Peço que adicione esse detalhe à sua conclusão.</s>
# </div>

# %% [markdown]
# ### DataFrame `aisles`

# %%
print(df_aisles.duplicated().sum())# Verifique se há linhas completamente duplicadas
# Out:
# 0

# %%
print(df_aisles['aisle_id'].duplicated().sum())# Verifique apenas se há IDs dos produtos duplicados
# Out:
# 0

# %% [markdown]
# Descreva brevemente suas conclusões e o que você fez com elas.

# %%
#primeiro vi se existe linha duplificada em todo o DF, depois especifiquei pra ver se existe na coluna id chegando a conclusao que nao existe valores duplicados nessa tabela

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
# <s>Existem valores duplicados nessa tabela? Peço que adicione esse detalhe à sua conclusão.</s>
# </div>

# %% [markdown]
# ### DataFrame `order_products`

# %%
print(df_order_products.duplicated().sum())# Verifique se há linhas completamente duplicadas
# Out:
# 0

# %%
print(df_order_products['order_id'].duplicated().sum())
print()
print(df_order_products['order_id'].duplicated().value_counts())
print(df_order_products[df_order_products.duplicated(subset=['order_id','product_id'])])
# Verifique mais uma vez se há outros casos complicados de duplicados
# Out:
# 4094961
#
# True     4094961
# False     450046
# Name: order_id, dtype: int64
# Empty DataFrame
# Columns: [order_id, product_id, add_to_cart_order, reordered]
# Index: []

# %% [markdown]
# Descreva brevemente suas conclusões e o que você fez com elas.

# %%
#A conclusao é que existem 4094961 linhas duplicados na coluna ID

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
# <s>
# Aqui você precisa verificar duplicados pelo subconjunto `order_id` e `product_id`. Sugestão:
#
# ```python
# df_order_products[df_order_products.duplicated(subset=['order_id','product_id'])]
# ...
# ```
# </s>
# </div>

# %% [markdown]
# ## Encontre e remova valores ausentes
#
#
# Ao processarmos valores duplicados, observamos que também temos valores ausentes que precisamos investigar nas seguintes colunas:
#
# *	A coluna `'product_name'` da tabela products.
# *	A coluna `'days_since_prior_order'` da tabela orders.
# *	A coluna `'add_to_cart_order'` da tabela order_products.

# %% [markdown]
# ### DataFrame `products`

# %%
product_name_isna = df_products['product_name'].isna().value_counts()
print( product_name_isna)# Encontre valores ausentes na coluna 'product_name'
# Out:
# False    48436
# True      1258
# Name: product_name, dtype: int64

# %% [markdown]
# Descreva brevemente suas conclusões.

# %%
#existem 1258 valores auxentes nessa doluna

# %%
# Filtrar as linhas
filtrar_product_names = df_products[df_products['product_name'].isna()]

# Verificar se todos os produtos ausentes
todos_aisle_100 = (filtrar_product_names['aisle_id'] == 100).all()

if todos_aisle_100:
    print("Todos estão associados ao ID 100.")
else:
    print("Nem todos estão associados ao ID 100.")

# Todos os nomes de produtos ausentes estão associados com o corredor de ID 100?
# Out:
# Todos estão associados ao ID 100.

# %% [markdown]
# Descreva brevemente suas conclusões.

# %%
# Verificar se todos os produtos ausentes 
todos_department_21 = (filtrar_product_names['department_id'] == 21).all()

if todos_department_21:
    print("Todos estão associados ao departamento de ID 21.")
else:
    print("Nem todos estão associados ao departamento de ID 21.")
# Todos os nomes de produtos ausentes estão associados com o departamento de ID 21?
# Out:
# Todos estão associados ao departamento de ID 21.

# %% [markdown]
# Descreva brevemente suas conclusões.

# %%
# Verificar ID 100
aisle_100_info = df_aisles[df_aisles['aisle_id'] == 100]

# Verificar ID 21
department_21_info = df_departments[df_departments['department_id'] == 21]

print("Corredor com ID 100:")
print(aisle_100_info)

print("\nDepartamento com ID 21:")
print(department_21_info)
# Use as tabelas department e aisle para verificar os dados do corredor com ID 100 e do departamento com ID 21.
# Out:
# Corredor com ID 100:
#     aisle_id    aisle
# 99       100  missing
#
# Departamento com ID 21:
#     department_id department
# 20             21    missing

# %% [markdown]
# Descreva brevemente suas conclusões.

# %%
df_products['product_name'].fillna('Unknown', inplace=True)

# Verificar se a operação foi realizada corretamente
print(df_products['product_name'].isna().sum()) 
# Deve retornar 0, indicando que não há mais valores ausentes
# Preencha nomes de produtos ausentes com 'Unknown'
# Out:
# 0

# %% [markdown]
# Descreva brevemente suas conclusões e o que você fez com elas.

# %%
#A operaçao foi realizada com sucesso e o resultado obtido é 0

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
# <s>Aqui você precisa adicionar suas observações sobre a seção acima.</s>
#
# </div>

# %% [markdown]
# ### DataFrame `orders`

# %%
print(df_orders.isna().sum())# Encontre os valores ausentes
# Out:
# order_id                      0
# user_id                       0
# order_number                  0
# order_dow                     0
# order_hour_of_day             0
# days_since_prior_order    28819
# dtype: int64

# %%
# Filtrar pedidos
prim_pedido = df_orders['order_number']

# Verificar valores ausentes
primeiro_pedido = prim_pedido.isna().sum()


if primeiro_pedido > 0:
    print('Existe valores ausentes nas colunas!\n')
    print(primeiro_pedido.sum())
    
else:
    print('Não existem valores ausentes nas colunas!\n')
    print(primeiro_pedido.sum())

# Há valores ausentes para os clientes que não estão fazendo o primeiro pedido?
# Out:
# Não existem valores ausentes nas colunas!
#
# 0

# %% [markdown]
# Descreva brevemente suas conclusões e o que você fez com elas.

# %%
#Não existem valores ausentes dos clientes que nao estao fazendo o primeiro pedido, o reusltado é zero 0

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
# <s>
# Aqui você precisa adicionar suas observações sobre a seção acima:
#
# >  Há valores ausentes para os clientes que não estão fazendo o primeiro pedido?
# </s>
# </div>

# %% [markdown]
# ### DataFrame `order_products`

# %%
print(df_order_products.isna().value_counts())# Encontre os valores ausentes
# Out:
# order_id  product_id  add_to_cart_order  reordered
# False     False       False              False        4544171
#                       True               False            836
# dtype: int64

# %%
print(df_order_products['add_to_cart_order'].min())
print()
print(df_order_products['add_to_cart_order'].max())
# Quais são os valores mínimo e máximo dessa coluna?
# Out:
# 1.0
#
# 64.0

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
# <s>Aqui você precisa calcular os valores mínimo e máximo para o atributo `add_to_cart_order`</s>
# </div>

# %% [markdown]
# Descreva brevemente suas conclusões.

# %%
#Atributo para (add_to_cart_order) é: 1 como o minimo, 999 como máximo

# %%
# Filtrar os pedidos onde 'add_to_cart_order' é ausente
missing_add_to_cart_order = df_order_products[df_order_products['add_to_cart_order'].isna()]

# Salvar os IDs desses pedidos em uma lista ou DataFrame
order_ids_with_missing_values = missing_add_to_cart_order['order_id'].unique()

print(order_ids_with_missing_values)
# Salve todos os IDs dos pedidos com pelo menos um valor ausente em 'add_to_cart_order'
# Out:
# [2449164 1968313 2926893 1717990 1959075  844733   61355  936852  264710
#  1564093  129627  293169 2849370 1386261 3308010  903110 2136777 3347453
#  1888628  165801 2094761 1038146 2997021  813364 2256933  171934 2409109
#  1730767 1169835  733526  404157 3125735  747668 1800005 1961723  871281
#   388234 1648217 1477139  102236 1021563 1832957 2721963  678116 1220886
#  1673227 2999801 1633337 2470674 2625444 1677118 2479011 3383594 1183255
#  1713430 2652650 1598369 1916118  854647 1302315  888470  180546 2621907
#  1308785 2729254    9310 2170451 2979697 1625713 1529171]

# %%
# Filtrar os pedidos onde 'add_to_cart_order' é ausente
missing_add_to_cart_order = df_order_products[df_order_products['add_to_cart_order'].isna()]

# Agrupar por 'order_id' e contar o número de 'product_id' em cada pedido
order_product_counts = missing_add_to_cart_order.groupby('order_id')['product_id'].count()

# Verificar o valor mínimo da contagem
min_product_count = order_product_counts.min()

print(f"O número mínimo em 'add_to_cart_order' é: {min_product_count}")
print()

# Todos os pedidos com valores ausentes contêm mais de 64 produtos?
if min_product_count > 64:
    print("Todos valores contêm mais de 64 produtos.")
else:
    print("Nem todos valotes contêm mais de 64 produtos.")

# Agrupe os pedidos com dados ausentes por ID de pedido
# Conte o número de 'product_id' em cada pedido e verifique o valor mínimo da contagem
# Out:
# O número mínimo em 'add_to_cart_order' é: 1
#
# Nem todos valotes contêm mais de 64 produtos.

# %% [markdown]
# Descreva brevemente suas conclusões.

# %%
# O número mínimo em 'add_to_cart_order' é: 1

# Nem todos valotes contêm mais de 64 produtos.

# %%
# Substituir 
df_order_products['add_to_cart_order'].fillna(999, inplace=True)

# Converter 
df_order_products['add_to_cart_order'] = df_order_products['add_to_cart_order'].astype(int)


print(df_order_products['add_to_cart_order'].isna().sum())  


# Substitua valores ausentes na coluna 'add_to_cart_order' por 999 e converta a coluna para o tipo integer
# Out:
# 0

# %% [markdown]
# Descreva brevemente suas conclusões e o que você fez com elas.

# %%
#todos os valores auxentes foram substituidos

# %% [markdown]
# ## Conclusões
#
# Escreva aqui suas conclusões intermediárias da Etapa 2. Preparação de dados

# %%
#Filtamos, agrupamos e agrupamos os dados de ofrma a ser mais facil de se analisar

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
# <s>Aqui você precisa adicionar suas observações sobre a seção acima</s>
#
# </div>

# %% [markdown]
# # Etapa 3. Análise de dados
#
# Quando os dados estiverem processados ​​e prontos, execute a seguinte análise:

# %% [markdown]
# # [A] Fácil (é necessário concluir tudo para passar)
#
# 1.	Verifique se os valores nas colunas `'order_hour_of_day'` e `'order_dow'` na tabela `orders` fazem sentido (ou seja, os valores da coluna  `'order_hour_of_day'` variam de 0 a 23 e os da `'order_dow'` variam de 0 a 6).
# 2.	Crie um gráfico que mostre quantas pessoas fazem pedidos a cada hora do dia.
# 3.	Crie um gráfico que mostre em que dia da semana as pessoas fazem compras.
# 4.	Crie um gráfico que mostre quanto tempo as pessoas esperam até fazer seu próximo pedido e comente sobre os valores mínimo e máximo.

# %% [markdown]
# ### [A1] Verifique se os valores fazem sentido

# %%
# Verificar valores na coluna 'order_hour_of_day'
hour_of_day_valid = df_orders['order_hour_of_day'].between(0, 23).all()
print(f"Os valores em 'order_hour_of_day' estão no intervalo esperado: {hour_of_day_valid}")
# Out:
# Os valores em 'order_hour_of_day' estão no intervalo esperado: True

# %%
# Verificar valores na coluna 'order_dow'
dow_valid = df_orders['order_dow'].between(0, 6).all()
print(f"Os valores em 'order_dow' estão no intervalo esperado: {dow_valid}")
# Out:
# Os valores em 'order_dow' estão no intervalo esperado: True

# %% [markdown]
# Escreva suas conclusões aqui

# %%
#Os valores de 'order_hour_of_day' e 'order_dow' fazem sentido

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
# <s>Aqui você precisa adicionar suas observações sobre a seção acima.</s>
#
# </div>

# %% [markdown]
# ### [A2] Quantas pessoas fazem pedidos a cada hora do dia?

# %%
# Contar o número de usuários 
users_per_hour = df_orders.groupby('order_hour_of_day')['user_id'].nunique()

# gráfico
plt.figure(figsize=(10, 6))
plt.bar(users_per_hour.index, users_per_hour.values, color='skyblue')
plt.xlabel('Hora do Dia')
plt.ylabel('Número de Pessoas')
plt.title('Número de Pessoas que Fazem Pedidos por Hora do Dia')
plt.xticks(range(0, 24))
plt.grid(axis='y')
plt.show()

# %% [markdown]
# Escreva suas conclusões aqui

# %%
#Cada barra representa uma hora do dia, e a altura da barra indica o número de usuários que fizeram pedidos naquela hora.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
# - O estudante analisou a distribuição de compras por hora do dia
# - As conclusões foram apresentadas
# </div>

# %% [markdown]
# ### [A3] Em que dia da semana as pessoas compram produtos alimentícios?

# %%
# Contar
orders_per_dow = df_orders['order_dow'].value_counts().sort_index()

# gráfico
plt.figure(figsize=(10, 6))
plt.bar(orders_per_dow.index, orders_per_dow.values, color='lightgreen')
plt.xlabel('Dia da Semana')
plt.ylabel('Número de Pedidos')
plt.title('Número de Pedidos por Dia da Semana')
plt.xticks(range(0, 7), ['Dom', 'Seg', 'Ter', 'Qua', 'Qui', 'Sex', 'Sab'])
plt.grid(axis='y')
plt.show()

# %% [markdown]
# Escreva suas conclusões aqui

# %%
# as pessoas fazem compra alimenticio todos os dias da semana com a maior intensidade nos finais de semana  principalmente nos domingos

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
# <s>Aqui você precisa adicionar suas observações sobre a seção acima.</s>
#
# </div>

# %% [markdown]
# ### [A4] Quanto tempo as pessoas esperam até fazer outro pedido?

# %% [markdown]
# Escreva suas conclusões aqui

# %%
# Calcular o tempo
df_orders_sorted = df_orders.sort_values(by=['user_id', 'order_number'])
df_orders_sorted['time_since_last_order'] = df_orders_sorted.groupby('user_id')['days_since_prior_order'].shift(0)

# Remover valores NaN
time_since_last_order = df_orders_sorted['time_since_last_order'].dropna()

plt.figure(figsize=(12, 6))
plt.hist(time_since_last_order, bins=50, color='lightcoral', edgecolor='black')
plt.xlabel('Dias até o Próximo Pedido')
plt.ylabel('Número de Pedidos')
plt.title('Distribuição do Tempo de Espera Entre Pedidos')
plt.grid(axis='y')
plt.show()

# Exibir estatísticas descritivas
print(f"Valor mínimo de tempo de espera: {time_since_last_order.min()} dias")
print(f"Valor máximo de tempo de espera: {time_since_last_order.max()} dias")
print(f"Média do tempo de espera: {time_since_last_order.mean()} dias")
# Out:
# Valor mínimo de tempo de espera: 0.0 dias
# Valor máximo de tempo de espera: 30.0 dias
# Média do tempo de espera: 11.101750979677794 dias

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
# <s>Aqui você precisa adicionar suas observações sobre a seção acima.</s>
#
# </div>

# %%
#as pessoas esperam em media 11 dias para fazer os pedidos

# %% [markdown]
# # [B] Médio (é necessário concluir tudo para passar)
#
# 1.	Há alguma diferença nas distribuições de `'order_hour_of_day'` nas quartas e sábados? Construa gráficos de barras para ambos os dias no mesmo gráfico e descreva as diferenças que você notou.
# 2.	Construa um gráfico de distribuição para o número de pedidos que os clientes fazem (ou seja, quantos clientes fizeram apenas 1 pedido, quantos fizeram apenas 2, quantos apenas 3, etc.)
# 3.	Quais são os 20 produtos comprados com mais frequência? Exiba os IDs e nomes.

# %% [markdown]
# ### [B1] Diferenças nas quartas e sábados em `'order_hour_of_day'`. Crie gráficos de barras para ambos os dias e descreva as diferenças.

# %%
df_quarta = df_orders[df_orders['order_dow'] == 3]  # Quarta-feira
df_sabado = df_orders[df_orders['order_dow'] == 6]  # Sábado

# %%
count_quarta = df_quarta['order_hour_of_day'].value_counts().sort_index()

# %%
count_sabado = df_sabado['order_hour_of_day'].value_counts().sort_index()

# %%
plt.figure(figsize=(14, 7))
plt.bar(count_quarta.index - 0.2, count_quarta.values, width=0.4, label='Quarta-feira', color='lightblue')
plt.bar(count_sabado.index + 0.2, count_sabado.values, width=0.4, label='Sábado', color='lightgreen')
plt.xlabel('Hora do Dia')
plt.ylabel('Número de Pedidos')
plt.title('Número de Pedidos por Hora do Dia (Quarta-feira vs. Sábado)')
plt.xticks(range(0, 24))
plt.legend()
plt.grid(axis='y')
plt.show()

# %% [markdown]
# Escreva suas conclusões aqui

# %%
#padrões nas horas de pico para quartas-feiras e sábados, destacando possíveis diferenças nos comportamentos de compra

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
# - O estudante comparou a distribuição de compras na Quarta-feira e no Sábado
# - As conclusões foram apresentadas
# </div>

# %% [markdown]
# ### [B2] Qual é a distribuição do número de pedidos por cliente?

# %%
# Contar o número de pedidos por cliente
orders_per_user = df_orders['user_id'].value_counts()

#quantidade de clientes que fizeram em pedidos
orders_distribution = orders_per_user.value_counts().sort_index()

# %%
# Configurar o tamanho do gráfico
plt.figure(figsize=(10, 6))

# Plotar ambos os histogramas no mesmo gráfico
plt.hist(orders_per_user, bins=50,
         alpha=0.7, color='skyblue',
         edgecolor='black',
         label='Número de Pedidos por Cliente')

plt.hist(orders_distribution.index.repeat(orders_distribution.values),
         bins=80, alpha=1,
         color='salmon',
         edgecolor='black',
         label='Quantidade de Clientes por Número de Pedidos')

# Configurar rótulos e título
plt.xlabel('Número de Pedidos')
plt.ylabel('Frequência')
plt.title('Comparação de Distribuição: Pedidos por Cliente vs. Quantidade de Clientes')
plt.grid(axis='y')

# Adicionar legenda
plt.legend()

# Mostrar o gráfico
plt.show()

# %% [markdown]
# Escreva suas conclusões aqui

# %%
#nota se que a grande maioria dos clientes fazem entre 1 a 5 pedidos com o número de cliente diminuindo a medida que numero de pedido aumenta

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
# <s>- Aqui você precisa plotar os dados acima usando um histograma.</s>
# </div>

# %% [markdown]
# ### [B3] Quais são os 20 produtos mais populares? Exiba os IDs e nomes.

# %%
df_merge = order_df.merge(product_df, on='product_id')

# %%
top_20_product_details=df_merge.groupby(['product_id', 'product_name'])['order_id'].count().sort_values(ascending=False).head(20).reset_index()

# %%
print("Os 20 produtos comprados com mais frequência são:")
print(top_20_product_details[['product_name']])
# Out:
# Os 20 produtos comprados com mais frequência são:
#                    product_name
# 24852                    Banana
# 13176    Bag of Organic Bananas
# 21137      Organic Strawberries
# 21903      Organic Baby Spinach
# 47209      Organic Hass Avocado
# 47766           Organic Avocado
# 47626               Large Lemon
# 16797              Strawberries
# 26209                     Limes
# 27845        Organic Whole Milk
# 27966       Organic Raspberries
# 22935      Organic Yellow Onion
# 24964            Organic Garlic
# 45007          Organic Zucchini
# 39275       Organic Blueberries
# 49683            Cucumber Kirby
# 28204        Organic Fuji Apple
# 5876              Organic Lemon
# 8277   Apple Honeycrisp Organic
# 40706    Organic Grape Tomatoes

# %% [markdown]
# Escreva suas conclusões aqui

# %%
#Os 20 produtos mais populares etao acima

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
# <s>
# - Aqui você precisa fazer o `merge` das tabelas de pedidos e produtos:
#     ```python
#     df_merge = order_df.merge(product_df, on='product_id')
#     df_merge.groupby(['product_id', 'product_name'])['order_id'].count().sort_values(ascending=False).head(20).reset_index()
#     ...
#     ```
# - Aqui você precisa apresentar suas observações sobre o resultado acima
# </s>
# </div>

# %% [markdown]
# # [C] Difícil (é necessário concluir pelo menos duas perguntas para passar)
#
# 1.	Quantos itens as pessoas normalmente compram em um pedido? Como fica a distribuição?
# 2.	Quais são os 20 principais itens incluídos mais frequentemente em pedidos repetidos? Exiba os IDs e nomes.
# 3.	Para cada produto, qual parcela de seus pedidos são repetidos? Crie uma tabela com colunas de ID e nome do produto e a proporção de pedidos repetidos.
# 4.	Para cada cliente, qual proporção de todos os seus pedidos são repetidos?
# 5.	Quais são os 20 principais itens que as pessoas colocam nos carrinhos antes de todos os outros? Exiba o ID do produto, nome e o número de vezes que ele foi o primeiro a ser adicionado a um carrinho.

# %% [markdown]
# ### [C1] Quantos itens as pessoas normalmente compram em um pedido? Como fica a distribuição?

# %%
items_per_order = df_order_products.groupby('order_id').size().mean()

# %%
print('Em média as pessoas pedem:\n', items_per_order.mean())
print()
plt.figure(figsize=(12, 6))
plt.hist(items_per_order, bins=range(1, items_per_order.max() + 1), edgecolor='black', color='skyblue')
plt.xlabel('Número de Itens por Pedido')
plt.ylabel('Número de Pedidos')
plt.title('Distribuição do Número de Itens por Pedido')
plt.grid(axis='y')
plt.show()
# Out:
# Em média as pessoas pedem:
#  10.098983215049127

# %% [markdown]
# Escreva suas conclusões aqui

# %%
#Em media as pessoas compram 10 itens por pedido

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
# <s>Aqui você precisa apresentar suas observações sobre o resultado acima.</s>
# </div>

# %% [markdown]
# ### [C2] Quais são os 20 principais itens incluídos com mais frequência em pedidos repetidos? Exiba os IDs e nomes.

# %%
# Filtrar pedidos que contêm itens repetidos
reordered_items = df_order_products[df_order_products['reordered'] == 1]

# Contar o número de vezes repetidos
reordered_item_counts = reordered_items['product_id'].value_counts()

# %%
top_20_reordered_items = reordered_item_counts.head(20).index

# Obter os detalhes 
top_20_reordered_item_details = df_products[df_products['product_id'].isin(top_20_reordered_items)]

# %%
# Ordenar os produtos pelo número de compras
top_20_reordered_item_details = top_20_reordered_item_details.set_index('product_id').loc[top_20_reordered_items]

# %%
print("Os 20 itens incluídos mais frequentemente em pedidos repetidos são:")
print(top_20_reordered_item_details[['product_name']])
# Out:
# Os 20 itens incluídos mais frequentemente em pedidos repetidos são:
#                    product_name
# 24852                    Banana
# 13176    Bag of Organic Bananas
# 21137      Organic Strawberries
# 21903      Organic Baby Spinach
# 47209      Organic Hass Avocado
# 47766           Organic Avocado
# 27845        Organic Whole Milk
# 47626               Large Lemon
# 27966       Organic Raspberries
# 16797              Strawberries
# 26209                     Limes
# 22935      Organic Yellow Onion
# 24964            Organic Garlic
# 45007          Organic Zucchini
# 49683            Cucumber Kirby
# 28204        Organic Fuji Apple
# 8277   Apple Honeycrisp Organic
# 39275       Organic Blueberries
# 5876              Organic Lemon
# 49235       Organic Half & Half

# %% [markdown]
# Escreva suas conclusões aqui

# %%
#Os 20 itens incluídos mais frequentemente em pedidos repetidos são estao apresentados acima

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
# <s>
# - O código acima não foi executado
# - Aqui você precisa apresentar suas observações sobre o resultado acima.
# </s>
#
# </div>

# %% [markdown]
# ### [C3] Para cada produto, qual parcela de todos os pedidos dele são repetidos?

# %%
#número total de pedidos que contêm cada produto
total_orders_per_product = df_order_products.groupby('product_id')['order_id'].nunique()

#número de pedidos repetidos que contêm cada produto
repeated_orders_per_product = df_order_products[df_order_products['reordered'] == 1].groupby('product_id')['order_id'].nunique().mean()

#proporção de pedidos repetidos para cada produto
repeat_proportion = repeated_orders_per_product / total_orders_per_product

# %%
#detalhes dos produtos
product_details = df_products.set_index('product_id').loc[repeat_proportion.index]

#nome do produto e proporção de pedidos repetidos
repeat_proportion_table = product_details[['product_name']].copy()
repeat_proportion_table['repeat_proportion'] = repeat_proportion

# %%
print("Proporção de Pedidos Repetidos para Cada Produto:")
print(repeat_proportion_table.sort_values(by='repeat_proportion', ascending=False).mean())
# Out:
# Proporção de Pedidos Repetidos para Cada Produto:
# repeat_proportion    0.486458
# dtype: float64

# %% [markdown]
# Escreva suas conclusões aqui

# %%
#Em media os produtos nao sao repetidos ou sao repetidos 0,5 vezes a cada pedido

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
# - Aqui você pode calcular a proporção diretamente usando o campo `reordered`. Sugestão:
#
# ```python
#
# df_merge.groupby(['...', '...'])['reordered'].mean().reset_index()
#
# ```
# </div>

# %% [markdown]
# ### [C4] Para cada cliente, qual proporção de todos os seus pedidos são repetidos?

# %%
# Contar o número total de pedidos por cliente
total_orders_per_user = df_orders.groupby('user_id')['order_id'].count()

# Filtrar pedidos com itens reordenados
repeated_orders = df_order_products[df_order_products['reordered'] == 1]

# Encontrar IDs de pedidos que contêm itens repetidos
repeated_order_ids = repeated_orders['order_id'].unique()

# %%
# Contar o número de pedidos repetidos por cliente
repeated_orders_per_user = df_orders[df_orders['order_id'].isin(repeated_order_ids)].groupby('user_id')['order_id'].count()

# Calcular a proporção de pedidos repetidos por cliente
repeat_proportion_per_user = (repeated_orders_per_user / total_orders_per_user).fillna(0)

# Exibir o resultado
print("Proporção de pedidos repetidos por cliente: \n", repeat_proportion_per_user.mean())
print(repeat_proportion_per_user)
# Out:
# Proporção de pedidos repetidos por cliente:
#  0.7414338029212935
# user_id
# 2         0.5
# 4         0.0
# 5         1.0
# 6         0.0
# 7         1.0
#          ...
# 206203    1.0
# 206206    1.0
# 206207    1.0
# 206208    1.0
# 206209    1.0
# Name: order_id, Length: 157437, dtype: float64

# %% [markdown]
# Escreva suas conclusões aqui

# %%
#Proporção de pedidos repetidos por cliente em media é de 0,75

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
# Essa tarefa também precisa de ajustes. Verifique o `join` que está sendo feito após as transformações. Para te ajudar a validar os seus cálculos, mostro o resultado esperado para alguns usuários abaixo.
#
# ```python
# user_id   reordered_ratio
# 2         0.038462
# 4         0.000000
# 5         0.666667
# 6         0.000000
# 7         0.928571
# ```
# </div>

# %% [markdown]
# ### [C5] Quais são os 20 principais itens que as pessoas colocam nos carrinhos antes de todos os outros?

# %%
# Filtrar itens adicionados primeiro
first_items = df_order_products[df_order_products['add_to_cart_order'] == 1]
item_counts = first_items['product_id'].value_counts().head(20)

# %%
# Juntar com df_products para obter os nomes
top_items = df_products[df_products['product_id'].isin(item_counts.index)]
top_items = top_items.set_index('product_id').reindex(item_counts.index)
top_items['frequency'] = item_counts.values

# %%
print("Top 20 Itens Adicionados Primeiro ao Carrinho:")
print(top_items['frequency'].reset_index().rename(columns={'index': 'product_id'}))
# Out:
# Top 20 Itens Adicionados Primeiro ao Carrinho:
#     product_id  frequency
# 0        24852      15562
# 1        13176      11026
# 2        27845       4363
# 3        21137       3946
# 4        47209       3390
# 5        21903       3336
# 6        47766       3044
# 7        19660       2336
# 8        16797       2308
# 9        27966       2024
# 10       44632       1914
# 11       49235       1797
# 12       47626       1737
# 13         196       1733
# 14       38689       1397
# 15       26209       1370
# 16       12341       1340
# 17        5785       1310
# 18       27086       1309
# 19       22935       1246

# %% [markdown]
# Escreva suas conclusões aqui

# %%
#Top 20 Itens Adicionados Primeiro ao Carrinho estao exibidos acima com os respetivos numero de vezes

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
# <s>Aqui você precisa apresentar suas observações sobre o resultado acima.</s>
# </div>

# %% [markdown]
# # Conclusão geral do projeto:

# %%
#Achei o projeto muito longo e demaisado dificil, alem de preciasr de ajudas constantes por causa da incerteza do que estva fazendo, tambem exixte a questão de escrever a conclusão para todo, mesmo para as questoes que se respondem por si proprios, minha sugestão era que dividissem essa STRING e o PROJECT em duas partes e aumentava pelo menos uma semana, assim não fica muito apertado.
